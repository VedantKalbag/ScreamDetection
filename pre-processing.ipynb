# %%
import os
import wave
import contextlib
import pandas as pd
import shutil
import audio_metadata

# %%
print(os.getcwd())
# Out:
# /Users/vedant/Desktop/Programming/scream-detection

# %% [markdown]
# # Pre-Processing the files
# Creating a band name-song name-video id lookup and renaming the file to the video id
# Video ID will be used to represent the files and the annotations, can be mapped back to song name using the lookup as required

# %%
df=pd.DataFrame()
band_name=[]
album_name=[]
video_id=[]
release_year=[]
song_name=[]
bit_depth=[] 
bitrate=[]
channels=[]
duration=[]
sample_rate=[]


loc='./resources/dataset/YTDownloads/'
for file_name in os.listdir(loc):
    if file_name.endswith(".wav"):
        #print(file_name)
        m1=audio_metadata.load(loc+file_name)
        bit_depth.append(m1['streaminfo']['bit_depth'])
        bitrate.append(m1['streaminfo']['bitrate'])
        channels.append(m1['streaminfo']['channels'])
        duration.append(m1['streaminfo']['duration'])
        sample_rate.append(m1['streaminfo']['sample_rate'])

        name=file_name[:-4]
        #print(name)
        #print(name[-11:])
        band_name_split=name.split(" - ")
        song_name_split=band_name_split[1].split(" (")
        if len(song_name_split) == 1:
            song_name_split=band_name_split[1].split("-")
        #print(band_name_split[0])
        #print(song_name_split[0])
        band=band_name_split[0]
        band_name.append(band)
        song=song_name_split[0]
        song_name.append(song)
        vid_id=name[-11:]
        video_id.append(vid_id)

        album_name.append("")
        release_year.append("")
        src='./resources/dataset/'+file_name
        dst='./resources/dataset/final/'+vid_id+'.wav'
        #shutil.copy2(src,dst)
        
    else:
        continue

df['band_name']=band_name
df['album_name']=album_name
df['song_name']=song_name
df['release_year']=release_year
df['duration_seconds']=duration
df['video_id']=video_id
df['bit_depth']=bit_depth
df['bitrate']=bitrate
df['channels']=channels

df['sample_rate']=sample_rate
df
# Out:
#              band_name album_name                     song_name release_year  \
# 0          Amon Amarth                Destroyer of the Universe
# 1          Suffocation                        Of the Dark Light
# 2             Behemoth             Ecclesia Diabolica Catholica
# 3          NECROPHOBIC                               Tsar Bomba
# 4              GODLESS                                Deathcult
# ..                 ...        ...                           ...          ...
# 116       Veil of Maya                                   Mikasa
# 117  Children Of Bodom                             In Your Face
# 118             Oceano                       District of Misery
# 119        Lamb of God                                  Redneck
# 120           Textures                       Old Days Born Anew
#
#      duration_seconds     video_id  bit_depth  bitrate  channels  sample_rate
# 0          224.188662  5aaOqUYG8Tw         16  1411200         2        44100
# 1          221.634467  rtnu49xY3iA         16  1411200         2        44100
# 2          324.336327  HKWqzjQAv14         16  1411200         2        44100
# 3          341.263673  LbLzL8akcX4         16  1411200         2        44100
# 4          250.984490  1CdtbR9JHCA         16  1411200         2        44100
# ..                ...          ...        ...      ...       ...          ...
# 116        189.916009  O4JU2QqQALs         16  1411200         2        44100
# 117        236.263039  5SgN5lvWZwQ         16  1411200         2        44100
# 118        194.699320  z6P3iCEEwmk         16  1411200         2        44100
# 119        248.546395  oqdZpxkzNvc         16  1411200         2        44100
# 120        337.362721  731QmPnjqe4         16  1411200         2        44100
#
# [121 rows x 10 columns]

# %%
df.to_csv('./resources/dataset/lookup_post120.csv',header=True, index=False,encoding='utf-8-sig')

# %%
audio_loc='./resources/dataset/Audio/'
annotation_loc='./resources/dataset/Annotations'
lookup_loc='./resources/dataset/lookup.csv'

# %%
lut=pd.read_csv(lookup_loc)
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(lut)
# Out:
#                   band_name                                         song_name  \
# 0        A Job for a Cowboy                           Entombment of a Machine
# 1                    Abbath                               Ashes Of The Damned
# 2                    Abbath                                      Harvest Pyre
# 3                    Abbath                             Nebular Ravens Winter
# 4                    Abbath                                       Winter Bane
# 5          After The Burial                                Lost In The Static
# 6                    Alcest                                          Eclosion
# 7               Amon Amarth                                           Aerials
# 8               Amon Amarth                         Destroyer of the Universe
# 9               Amon Amarth                               Free Will Sacrifice
# 10              Amon Amarth                                 Live For The Kill
# 11              Amon Amarth                                    Slaves of Fear
# 12              Amon Amarth                       Twilight Of The Thunder God
# 13                 Be'lakor                                          Abeyance
# 14                 Be'lakor                                           Venator
# 15                 Behemoth                                         Bartzabel
# 16                 Behemoth                        Blow Your Trumpets Gabriel
# 17                 Behemoth                      Ecclesia Diabolica Catholica
# 18           Born of Osiris                                        Divergency
# 19           Born of Osiris                                        White Nile
# 20           Born of Osiris                                           Machine
# 21          Cannibal Corpse                      High Velocity Impact Spatter
# 22      Cattle Decapitation      A Living, Breathing Piece of Defecating Meat
# 23      Cattle Decapitation                             Bring Back the Plague
# 24      Cattle Decapitation                        Forced Gender Reassignment
# 25      Cattle Decapitation                              Manufactured Extinct
# 26        Children of Bodom                                  Are You Dead Yet
# 27        Children of Bodom                                   Everytime I Die
# 28        Children of Bodom                                      In Your Face
# 29        Children of Bodom                               Hate Crew Deathroll
# 30        Children of Bodom                                  Living Dead Beat
# 31        Children of Bodom                                       Needled 247
# 32        Children of Bodom                                        Sixpounder
# 33        Children of Bodom                            Under Grass And Clover
# 34                    DEATH                                     Pull the Plug
# 35                    DEATH                                   The Philosopher
# 36              DECAPITATED                                      Blood Mantra
# 37              DECAPITATED                                        Earth Scar
# 38              DECAPITATED                                     Kill The Cult
# 39             Dark Funeral                            Nail Them To The Cross
# 40        Dark Tranquillity                                             Atoma
# 41        Dark Tranquillity                                    Lost to Apathy
# 42        Dark Tranquillity                                    Misery's Crown
# 43   Devin Townsend Project                                      Stormbending
# 44                 ENSLAVED                      Caravans To The Outer Worlds
# 45                Ensiferum                               In My Sword I Trust
# 46                Ensiferum                                       Lai Lai Hei
# 47                Ensiferum                                Way of the Warrior
# 48                  GODLESS                                         Deathcult
# 49                   Gojira                                           Silvera
# 50                   Gojira                                          Stranded
# 51                 IMMORTAL                                    ALL SHALL FALL
# 52                 IMMORTAL                               Northern Chaos Gods
# 53                In Flames                                   Cloud Connected
# 54                KATAKLYSM                                   The Black Sheep
# 55                   Kalmah                                      Heroes To Us
# 56                   Kalmah                                      The Evil Kin
# 57              Lamb of God                                            Embers
# 58              Lamb of God                                      Laid to Rest
# 59              Lamb of God                                      Memento Mori
# 60              Lamb of God               Now You've Got Something to Die For
# 61              Lamb of God                                            Omerta
# 62              Lamb of God                                          Overlord
# 63              Lamb of God                                           Redneck
# 64              Lamb of God                                    The Faded Line
# 65              Lamb of God                              Walk with Me In Hell
# 66              Linkin Park                                          Given Up
# 67                 MASTODON                                 Blood and Thunder
# 68                MESHUGGAH                                             Bleed
# 69              NECROPHOBIC                                        Tsar Bomba
# 70                Nevermore                                              Born
# 71          Ne Obliviscaris               And Plague Flowers the Kaleidoscope
# 72          Ne Obliviscaris              Devour Me Colossus Part I Blackholes
# 73          Ne Obliviscaris                                       Intra Venus
# 74          Ne Obliviscaris      Painters of the Tempest Part II Triptych Lux
# 75          Ne Obliviscaris                                           Pyrrhic
# 76          Ne Obliviscaris  Urn Part I And Within the Void We Are Breathless
# 77          Ne Obliviscaris           Urn Part II As Embers Dance In Our Eyes
# 78                Nevermore                             This Godless Endeavor
# 79                Northlane                                         Clockwork
# 80                   Oceano                                District of Misery
# 81            Of Mice & Men                                     Bones Exposed
# 82            Of Mice & Men                                          Obsolete
# 83                    Opeth                                   Blackwater Park
# 84                    Opeth                                       Deliverance
# 85                    Opeth                                Ghost of Perdition
# 86                    Opeth                                 The Drapery Falls
# 87                    Opeth                                   The Lotus Eater
# 88            Parkway Drive                                           Carrion
# 89                Periphery                                       Blood Eagle
# 90                Periphery                                          Marigold
# 91           Porcupine Tree                                              Halo
# 92           Porcupine Tree                                          Open Car
# 93          Rings of Saturn                              No Pity for a Coward
# 94          Rings of Saturn                                Senseless Massacre
# 95      STRAPPING YOUNG LAD                                              Love
# 96          SUICIDE SILENCE                                         Disengage
# 97          SUICIDE SILENCE                               Slaves To Substance
# 98                   Slayer                                   South Of Heaven
# 99                   Slayer                                      War Ensemble
# 100                Slipknot                                      All Out Life
# 101                Slipknot                                      Psychosocial
# 102             Suffocation                       Clarity Through Deprivation
# 103             Suffocation                           Effigy of the Forgotten
# 104             Suffocation                              Infecting the Crypts
# 105             Suffocation                                 Of the Dark Light
# 106         Suicide Silence                                You Only Live Once
# 107               TESSERACT                                          Nocturne
# 108       THY ART IS MURDER                                 Reign Of Darkness
# 109                    TOOL                                   Ticks & Leeches
# 110               Testament                          Brotherhood of the Snake
# 111                Textures                              Laments Of An Icarus
# 112                Textures                                Old Days Born Anew
# 113                Textures                                     Storm Warning
# 114            Veil of Maya                                            Mikasa
# 115            Veil of Maya                                          Outsider
# 116            Veil of Maya                                         Overthrow
# 117             Whitechapel                                The Saw Is the Law
# 118               Wintersun                               Beautiful Death 2.0
# 119               Wintersun                          Sons of Winter and Stars
# 120               Wintersun                                     Starchild 2.0
# 121               Wintersun                                              Time
#
#         video_id
# 0    nOJHbpijw3o
# 1    K5pMoSECagE
# 2    T_qa-wNbC4w
# 3    QJyTW1-Piwo
# 4    yLdJSQDmVXw
# 5    hUNAX1UYeAE
# 6    V-x87xt6rzU
# 7    VnoGQMJKDr4
# 8    5aaOqUYG8Tw
# 9    OjIYTgannxc
# 10   Bh_5ofa__pY
# 11   MyVHiHxPdjU
# 12   edBYB1VCV0k
# 13   rYBgWgjjgxQ
# 14   ainbICPRV8Y
# 15   Dhfy9TPga-c
# 16   Czx-OIyrQwQ
# 17   HKWqzjQAv14
# 18   L9ABuasa1Cc
# 19   4ShzP_M7W-k
# 20   Y4OJzu97kEw
# 21   B3F10hXdmQY
# 22   oWeTeFn0LhM
# 23   lXGSLKWeVwE
# 24   tn4QjKcik8U
# 25   u8t8g8lU4ms
# 26   aNJXS9X0yY0
# 27   5cEK1OLhUKQ
# 28   5SgN5lvWZwQ
# 29   6m0Pv-GyJ9I
# 30   gG3JZ5vGJsk
# 31   zVZ9VSm6VAk
# 32   09KScSe4hIc
# 33   1gpfzCxiQ-A
# 34   _duhhVa-dk8
# 35   8256VJ4hkJU
# 36   8gILuUdY2cU
# 37   yR7AnukIl8U
# 38   kQUTQTNChbE
# 39   plh22lTpnjY
# 40   C_voh9WFbsM
# 41   GZqfH1LQEOQ
# 42   NKjzDU7V7es
# 43   YhcoLO8vZZU
# 44   ErTgN2zoTkA
# 45   -2WqQY_xSSM
# 46   uEqsfYLRqDc
# 47   PcxBjFK12zg
# 48   1CdtbR9JHCA
# 49   iVvXB-Vwnco
# 50   FNdC_3LR2AI
# 51   sOOebk_dKFo
# 52   c5uP9PlEDro
# 53   B7iIS91fMAc
# 54   V-KME77Pi60
# 55   o1c0NCjFxj0
# 56   YT1dFV-9V_k
# 57   SCVvhUW7cxo
# 58   HL9kaJZw8iw
# 59   hBj0-dIU8HI
# 60   0m5fIHHfJTw
# 61        #NAME?
# 62   RNRsvFsY9qk
# 63   oqdZpxkzNvc
# 64   JuRRnVqv2Vc
# 65   QWkhCxCcWSE
# 66   0xyxtzD54rM
# 67   labytsb3gfI
# 68   qc98u-eGzlc
# 69   LbLzL8akcX4
# 70   impRqn44OCA
# 71   BNyYiTdqzAY
# 72   pSqWrQym3SM
# 73   UgUn4EKLMnU
# 74   SEMiTqiFnNw
# 75   dCyxGNbBWAk
# 76   pnyoRKNk7sQ
# 77   u9XLeME2Ie8
# 78   yxUnhbaGap8
# 79   TwyvWR25FsE
# 80   z6P3iCEEwmk
# 81   IO-JbFtgeX4
# 82   hxu3KXVy48w
# 83   j4xCb_OU_lM
# 84   rggQNCS8UjM
# 85   MDBykpSXsSE
# 86   YeTNkPXRrVY
# 87   XhohQNdSt7g
# 88   BR2kSva4NT8
# 89   SzznL_8DIUM
# 90   rmtU2WJfPgU
# 91   nKE9RJVaFlA
# 92   XehrSkDKupA
# 93   hwxTEcHnC1o
# 94   F3A_3c882us
# 95   LeG-6bpeUkA
# 96   FukeNR1ydOA
# 97   k27N-jRofrM
# 98   74nTzbgDGWM
# 99   jqnC54vbUbU
# 100  wLoYIBEZEfw
# 101  5abamRO41fE
# 102  HUUBI7RJtr8
# 103  taj7UfkahNE
# 104  P8iinvFR1a0
# 105  rtnu49xY3iA
# 106  ds9s-pzGD0M
# 107  get0cXOsSXg
# 108  47Plg93oJ1M
# 109  q0BOpkA2Vs4
# 110  oIvj-uYq9So
# 111  ZeYZxq4tRwE
# 112  731QmPnjqe4
# 113  4600fGWcn9o
# 114  O4JU2QqQALs
# 115  Rlh_hxjmSvc
# 116  GLu-E42-RmA
# 117  rQqgjVAklHQ
# 118  TNg-mfVnCWk
# 119  ttoJ-Ro0L04
# 120  oyuOjCfCsm4
# 121  ebSxxr726_8

# %%
import audio_metadata
i=1
loc='./resources/dataset/YTDownloads/'
for file_name in os.listdir(audio_loc):
    if file_name.endswith(".wav"):
        #print(audio_loc+file_name)
        m1=audio_metadata.load(audio_loc+file_name)

# %%
m1['streaminfo']['bit_depth']
m1['streaminfo']['bitrate']
m1['streaminfo']['channels']
m1['streaminfo']['duration']
m1['streaminfo']['sample_rate']
# Out:
# 44100

# %%
m1
# Out:
# <WAVE({
#     'filepath': '/Users/vedant/Desktop/Programming/scream-detection/resources/dataset/Audio/c5uP9PlEDro.wav',
#     'filesize': '44.65 MiB',
#     'pictures': [],
#     'streaminfo': <WAVEStreamInfo({
#         'audio_format': <WAVEAudioFormat.PCM>,
#         'bit_depth': 16,
#         'bitrate': '1411 Kbps',
#         'channels': 2,
#         'duration': '04:25',
#         'sample_rate': '44.1 KHz',
#     })>,
#     'tags': <RIFFTags({'ISFT': ['Lavf58.76.100']})>,
# })>

# %%
m1['streaminfo']['duration']
# Out:
# 337.36272108843536

# %%
# Out:
# 0:05:37.362721

# %% [markdown]
# # RUN THE BELOW TWO PARAGRAPHS EVERY TIME THE DATASET IS UPDATED/ADDED TO

# %% [markdown]
# # Processing the annotatated values into the easy to work with schema

# %%
loc='./resources/dataset/Annotations/labelled/'
for file_name in os.listdir(loc):
    if file_name.endswith(".csv"):
        video_id=file_name[:-4]
        df=pd.read_csv(loc+file_name,names=['sample_number','event'])
        try:
            df[['event','number','scream_type']]=df['event'].str.split('_',expand=True)
            #df['number']=df['number'].astype(int)
            #df
            df['number']=df['number'].astype(int)
            #df
            df1=df.pivot('number','event',['sample_number','scream_type'])
            df1.columns = [ '_'.join(x) for x in df1.columns ]
            try:
                df1=df1[['sample_number_start','sample_number_end','scream_type_start']]
            except:
                df1=df1[['sample_number_start','sample_number_stop','scream_type_start']]
            df1.columns=['sample_start','sample_end','scream_type']
            df1['video_id']=video_id
            df1.to_csv('./resources/dataset/Annotations/processed/'+file_name,header=True, index=False,encoding='utf-8-sig')
        except:
            print(f"The event field has incorrect data for {video_id}")

# %% [markdown]
# # Convert all sample numbers to their corresponding timestamps, based on the sample rate from the lookup table so that when resampling the annotations do not get ruined

# %%
import pandas as pd
csv_loc = './resources/dataset/Annotations/processed/'
audio_loc = './resources/dataset/Audio/'
output_loc = './resources/dataset/Annotations/timestamps/'

lut = pd.read_csv('./resources/dataset/lookup_new.csv')
for file_name in os.listdir(csv_loc):
    if file_name.endswith(".csv"):
        video_id=file_name[:-4]
        df=pd.read_csv(csv_loc + file_name)
        #tmp = df.join(lut.set_index('video_id'),on = 'video_id')
        tmp=lut[lut['video_id'] == video_id]
        sr = tmp['sample_rate'].iloc[0]
        df.insert(2, 'timestamp_start', round(df['sample_start']/sr,2))
        df.insert(3, 'timestamp_end', round(df['sample_end']/sr,2))
        df.insert(0,'file_name',video_id+'.wav')
        #df.insert()
        #print(sr)
        #print(df)
        df.to_csv(output_loc + video_id + '.csv',header=True, index=False,encoding='utf-8-sig')

# %%
df.columns
# Out:
# Index(['file_name', 'sample_start', 'sample_end', 'timestamp_start',
#        'timestamp_end', 'scream_type', 'video_id'],
#       dtype='object')

# %% [markdown]
# # Combining all annotations into one file for input into KNN

# %%
import pandas as pd
csv_loc = './resources/dataset/Annotations/processed/'
audio_loc = './resources/dataset/Audio/'
timestamp_loc = './resources/dataset/Annotations/timestamps/'

output_loc = './resources/dataset/Annotations/final/'
df1=pd.DataFrame()
i = 0
for file_name in os.listdir(timestamp_loc):
    if file_name.endswith(".csv"):
        #print(file_name)
        if i == 0:
            df1=pd.read_csv(timestamp_loc+file_name,names=['file_name','sample_start','sample_end','timestamp_start','timestamp_end','scream_type','video_id'],header=0)
            i=1
        else:
            temp=pd.read_csv(timestamp_loc+file_name,names=['file_name','sample_start','sample_end','timestamp_start','timestamp_end','scream_type','video_id'],header=0)
            df1=pd.concat([df1,temp],axis=0,ignore_index=True)

df1.to_csv(output_loc + 'annotation.csv',header=True, index=False,encoding='utf-8-sig')

# %%
df1
# Out:
#             file_name  sample_start  sample_end  timestamp_start  \
# 0     4600fGWcn9o.wav       1579017   1999183.0            35.81
# 1     4600fGWcn9o.wav       2020012   2152867.0            45.81
# 2     4600fGWcn9o.wav       2161887   2486176.0            49.02
# 3     4600fGWcn9o.wav       2488192   2795520.0            56.42
# 4     4600fGWcn9o.wav       2797600   3030794.0            63.44
# ...               ...           ...         ...              ...
# 1570  0m5fIHHfJTw.wav       6819456   6915072.0           154.64
# 1571  0m5fIHHfJTw.wav       7056672   7172928.0           160.02
# 1572  0m5fIHHfJTw.wav       7264704   7286880.0           164.73
# 1573  0m5fIHHfJTw.wav       7789376   8205120.0           176.63
# 1574  0m5fIHHfJTw.wav       8223488   8530272.0           186.47
#
#       timestamp_end scream_type     video_id
# 0             45.33      midfry  4600fGWcn9o
# 1             48.82      midfry  4600fGWcn9o
# 2             56.38      midfry  4600fGWcn9o
# 3             63.39       clean  4600fGWcn9o
# 4             68.73      midfry  4600fGWcn9o
# ...             ...         ...          ...
# 1570         156.80      midfry  0m5fIHHfJTw
# 1571         162.65      midfry  0m5fIHHfJTw
# 1572         165.24      midfry  0m5fIHHfJTw
# 1573         186.06      midfry  0m5fIHHfJTw
# 1574         193.43      midfry  0m5fIHHfJTw
#
# [1575 rows x 7 columns]
